# %% [markdown]
# # PyView - Interactive NetCDF Viewer
#
# **A Python-based interactive netCDF viewer for Jupyter notebooks**
#
# 🎯 **Purpose**: Provides ncview-like functionality optimized for remote server usage without X11 forwarding
#
# ✨ **Key Features**:
# - ?️ **Interactive Maps**: Geographic visualization with depth navigation
# - 🌊 **Depth Profiles**: Vertical profiles with location selection
# - 🎛️ **Smart Sliders**: Navigate dimensions with real coordinate values
# - 📊 **Real-time Statistics**: Automatic min, max, mean, std updates
# - 🎨 **Customizable**: Multiple colormaps and plot options
# - 🔒 **Contained Plotting**: All plots stay within the widget interface
#
# ## Quick Start
#
# ```python
# from pyview_ultimate import ultimate_pyview
#
# # Open your netCDF file
# viewer = ultimate_pyview('/path/to/your/file.nc')
# ```

# %% [markdown]
# # Usage Guide
#
# ## Basic Usage
# ```python
# from pyview import pyview
#
# # Open any netCDF file
# viewer = ultimate_pyview('/path/to/your/file.nc')
# ```
#
# ## Layout & Interface
#
# ### 📱 **Ultra-Compact Layout**
# - **Top row**: Variable selector and colormap side-by-side
# - **Statistics row**: Min, Max, Mean, Valid count horizontally
# - **Plot dimensions**: Checkboxes in horizontal rows (3 per row)
# - **Navigation sliders**: Grouped horizontally (2 per row) with coordinates
# - **Quick presets**: Action buttons in one row
# - **Plot area**: Optimized 800×500px visualization
# - **Result**: Maximum information density, no scrolling needed
#
# ### 🎯 **Space-Efficient Design**
# - **Horizontal grouping**: Everything organized in rows instead of columns
# - **Compact widgets**: Smaller, optimized component sizes
# - **Smart organization**: Related controls grouped together
# - **Responsive layout**: Perfect for laptop screens
#
# ## Features
#
# ### 🗺️ **Map View**
# - Click "Map View" button for geographic plots
# - Shows lat × lon maps with optimal proportions
# - Use depth slider to navigate ocean levels
# - Perfect for visualizing spatial patterns
#
# ### 🌊 **Depth Profile**
# - Click "Depth Profile" button for vertical sections
# - Shows depth vs variable value
# - Use lat/lon sliders to select location
# - Great for analyzing vertical structure
#
# ### 🎛️ **Interactive Controls**
# - **Variable Dropdown**: Select data to visualize
# - **Plot Checkboxes**: Choose dimensions (arranged horizontally)
# - **Navigation Sliders**: Move through dimensions (2 per row)
# - **Coordinate Display**: Real-time position values
# - **Statistics Panel**: Live min/max/mean/valid in one row
# - **Colormap Selector**: Choose visualization style
# - **Quick Presets**: One-click common views
#
# ### 💡 **Tips**
# - All plots stay contained within the widget
# - Ultra-compact design fits everything on screen
# - Statistics and sliders update in real-time
# - Checkboxes organized in rows for easy scanning
# - Sliders grouped with coordinate displays
# - Works perfectly on remote servers without X11
#
# ## Perfect for Ocean Data! 🌊
# This viewer is optimized for ocean model output with depth, latitude, and longitude dimensions.

# %%
from pyview import pyview

# %%
file_path = "/Users/hofmann/Documents/bern3D/bern3d_f90/input/world_68x46.observations.nc"
file_path = "/Users/hofmann/Documents/ocean_modelling/pyview/RUNNAME.00001765_full_ave.nc"
ncview_viewer = pyview(file_path)
# Out:
#             <style>
#             /* Light theme for PyView */
#             .widget-html, .widget-html-content {
#                 background-color: #ffffff !important;
#                 color: #2d3748 !important;
#             }
#
#             .widget-dropdown select, .widget-text input {
#                 background-color: #ffffff !important;
#                 color: #2d3748 !important;
#                 border: 1px solid #cbd5e0 !important;
#             }
#
#             .widget-dropdown select:focus, .widget-text input:focus {
#                 border-color: #3182ce !important;
#                 box-shadow: 0 0 0 1px #3182ce !important;
#             }
#
#             .widget-button {
#                 background-color: #f7fafc !important;
#                 color: #2d3748 !important;
#                 border: 1px solid #cbd5e0 !important;
#             }
#
#             .widget-button:hover {
#                 background-color: #edf2f7 !important;
# ...
